-- %% [markdown]
-- # [aga]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [aga]    Script Date: 12.09.2022 12:09:54 ******/
CREATE DATABASE [aga]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'aga', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL14.MSSQLSERVER\MSSQL\DATA\aga.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB ),
( NAME = N'qq', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL14.MSSQLSERVER\MSSQL\DATA\qq.ndf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'aga_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL14.MSSQLSERVER\MSSQL\DATA\aga_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
ALTER DATABASE [aga] SET COMPATIBILITY_LEVEL = 140
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [aga].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [aga] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [aga] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [aga] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [aga] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [aga] SET ARITHABORT OFF 
GO
ALTER DATABASE [aga] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [aga] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [aga] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [aga] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [aga] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [aga] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [aga] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [aga] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [aga] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [aga] SET  DISABLE_BROKER 
GO
ALTER DATABASE [aga] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [aga] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [aga] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [aga] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [aga] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [aga] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [aga] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [aga] SET RECOVERY FULL 
GO
ALTER DATABASE [aga] SET  MULTI_USER 
GO
ALTER DATABASE [aga] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [aga] SET DB_CHAINING OFF 
GO
ALTER DATABASE [aga] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [aga] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [aga] SET DELAYED_DURABILITY = DISABLED 
GO
EXEC sys.sp_db_vardecimal_storage_format N'aga', N'ON'
GO
ALTER DATABASE [aga] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [sus]

-- %%
USE [aga]
GO

-- %%
/****** Object:  User [sus]    Script Date: 12.09.2022 12:09:54 ******/
CREATE USER [sus] FOR LOGIN [sus] WITH DEFAULT_SCHEMA=[sus]
GO

-- %% [markdown]
-- # [sus]

-- %%
/****** Object:  Schema [sus]    Script Date: 12.09.2022 12:09:54 ******/
CREATE SCHEMA [sus]
GO

-- %% [markdown]
-- # [dbo].[Поддержка]

-- %%
/****** Object:  Table [dbo].[Поддержка]    Script Date: 12.09.2022 12:09:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Поддержка](
	[Телефон] [nchar](10) NULL,
	[Эл.Почта] [nchar](10) NULL,
	[айди] [int] NOT NULL,
 CONSTRAINT [PK_Поддержка] PRIMARY KEY CLUSTERED 
(
	[айди] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Пользователи]

-- %%
/****** Object:  Table [dbo].[Пользователи]    Script Date: 12.09.2022 12:09:54 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Пользователи](
	[Логин] [nchar](10) NULL,
	[Пароль] [nchar](10) NULL,
	[Имя] [nchar](10) NULL,
	[айди] [int] NOT NULL,
 CONSTRAINT [PK_Пользователи] PRIMARY KEY CLUSTERED 
(
	[айди] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [aga]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [aga] SET  READ_WRITE 
GO
